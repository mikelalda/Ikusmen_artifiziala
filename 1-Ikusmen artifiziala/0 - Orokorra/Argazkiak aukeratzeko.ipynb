# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

import os
from IPython.display import Image
@interact
def show_images(file=os.listdir('Argazkiak/')):
    fdir='Argazkiak/'
    display(Image(fdir+file))
# Out:
# interactive(children=(Dropdown(description='file', options=('01.JPG', 'adaptive.png', 'adaptive_new_1.png', 'a…

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
@interact
def show_articles_more_than(r=(0, 255, 1),g=(0, 255, 1),b=(0, 255, 1)):
    img = np.zeros((300,512,3), np.uint8)
    img[:] = [r,g,b]
    plt.imshow(img)
# Out:
# interactive(children=(IntSlider(value=127, description='r', max=255), IntSlider(value=127, description='g', ma…
