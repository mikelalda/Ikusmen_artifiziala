# %% [markdown]
# # Jupyter notebook

# %% [markdown]
# Jupyter erreminta erabilgarria izan daiteke ikasterako garaian eta programa baten exekuzioa analizatzerako garaian. Honen erabilera errazteko gida txiki onetan Markdown eta Code atalak landuko ditugu. Edozein kode lantzeko egindako aplikazio bat da, baina Windows sistema eragilean Python eta R bakarrik erabili daitezke, nahiz eta online lan egitea dagoen berarekin.

# %% [markdown]
# [Online lan egiteko weborria](https://jupyter.org/try)

# %% [markdown]
# - Markdown idazteko erabiliko da, baina ez da bloc de notas bat izango, hau da, egitura ematea edukiko dugu.
# - Code idatzitako kodearentzat erabiliko da, hanbat gelaxkatan banatu daiteke eta gelaxkak banan-bana exekutatzen joan bere funtzionamendua ikusi ahal izateko.

# %% [markdown]
# **Aukeraketa honela egingo dugu:**
# - Erabiliko dugun gelaxkaren hizkuntza (Markdown edo Code) aukeratu beharko ditugu:
# ![01.JPG](attachment:01.JPG)

# %% [markdown]
# -----------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------

# %% [markdown]
# ## Markdown

# %% [markdown]
# Herreminta honen hasierako erabilera ikasteko [tutorial](https://commonmark.org/help/tutorial/) bat dago 10 minutun egin daitekeena.

# %% [markdown]
# **Laburpena**
#
#
# \*cursiva* = *cursiva*
#
# \*\*negrita** = **negrita**
#
# - marka egiteko "- marka" jarriko dugu
#
# \\ jarriko da zerbaitek hizkiei eraginik egitea ezbadugu nahi \\* esaterako

# %% [markdown]
# --------------------

# %% [markdown]
# \\ jarriko da esaldi baten amaiera linea huts bat uzteko bi paragraforen artean edo bestela intro botoiarekin ere egin daiteke.
#
# \#a egiten badugu ondorengoa egingo du
# # a
# \##a egiten badugu ondorengoa egingo du
# ## a
# \###a egiten badugu ondorengoa egingo du
# ### a

# %% [markdown]
# --------------------

# %% [markdown]
# \> saltoak egiteko barrurantz
#
# \> saltoa jarriz
# > saltoa
#
# \> > bi salto jarriz
# > > bi salto
#
#
#
# Listak egiten joateko
# \1. mikel
#
# \1) mikel

# %% [markdown]
# --------------------

# %% [markdown]
# Linka \[Idatzia](linka)
#
# [Idatzia](linka)
#
#
# Argazkiak sartzeko, posible da arrastatzea edota kodigoa idaztea ![01.JPG]\(attachment:01.JPG\) esaterako.
#
#
# kodea idazteko \`x = 3\` bezala idatziko da `x = 3`

# %% [markdown]
# --------------------

# %% [markdown]
# \* Fruit (intro eta bi hustune utzi)
#   \* Apple (intro eta bi hustune utzi)
#   \* Orange
#
# * Fruit
#   * Apple
#   * Orange

# %% [markdown]
# --------------------

# %% [markdown]
# Funtzio bereziak \$\frac{R^2}{r_2}$  $R^{e^2}_s$ $R^{e^2}{_s}$

# %% [markdown]
# --------------------

# %% [markdown]
# Bere erabilera zehatzagoa jakin nahi bada [mastering markdown](https://guides.github.com/features/mastering-markdown/) edo [markdown-cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) webguneetara jotzea gomendatzen da.

# %% [markdown]
# Azalpen gehiagorako hemen duzue esteka ingelesezko azalpenekin: https://notebooks.gesis.org/binder/jupyter/user/ipython-ipython-in-depth-xaspfb05/notebooks/binder/Index.ipynb
